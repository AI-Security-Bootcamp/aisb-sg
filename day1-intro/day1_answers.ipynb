# %%
import json
import math
import os
import sys
from collections.abc import Callable
from pathlib import Path

import tiktoken # Library for tokenizing text 
from transformers import AutoTokenizer

from openai import OpenAI
from openai.types.chat import ChatCompletionMessageParam

'''
for _path in [
    str(Path(__file__).resolve().parent),
    str(Path(__file__).resolve().parent.parent),
]:
    if _path not in sys.path:
        sys.path.insert(0, _path)
'''

from aisb_utils import report
from aisb_utils.env import load_dotenv

load_dotenv()

# OpenRouter client
print("Instantiating OpenRouter client...")
openrouter_client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.environ.get("OPENROUTER_API_KEY", ""),
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 23
#      12 from openai.types.chat import ChatCompletionMessageParam
#      14 '''
#      15 for _path in [
#      16     str(Path(__file__).resolve().parent),
#    (...)     20         sys.path.insert(0, _path)
#      21 '''
# ---> 23 from aisb_utils import report
#      24 from aisb_utils.env import load_dotenv
#      26 load_dotenv()
#
# ModuleNotFoundError: No module named 'aisb_utils'
